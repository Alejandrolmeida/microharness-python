# %% [markdown]
# # 07 · FastAPI + AG-UI
#
# La capa HTTP publica el agente por AG-UI y ofrece un endpoint JSON estable para integraciones sencillas.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.server import create_app

app = create_app()
sorted(route.path for route in app.routes if hasattr(route, 'path'))

# %% [markdown]
# Para ejecutar el servidor desde una terminal: `python -m microharness.server`. El endpoint `/agent` requiere modelo configurado; `/api/chat` puede devolver una respuesta de referencia si no hay credenciales.
