# %% [markdown]
# # 07 · FastAPI + AG-UI con variante MAF-native
#
# El servidor publica dos recorridos: el microharness original y la variante MAF-native. Aquí verificamos que las rutas nativas están registradas.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.server import create_app

app = create_app()
routes = sorted(route.path for route in app.routes if hasattr(route, "path"))
[path for path in routes if "agent" in path or "chat" in path]

# %% [markdown]
# Ejecución recomendada: arranca `python -m microharness.server` y compara `python scripts/run_request.py` frente a `python scripts/run_native_request.py`. La segunda ruta usa `AgentSession`, providers de contexto/memoria/todos y middleware MAF.
