# %% [markdown]
# # 02 · Tools y contexto controlado
#
# Objetivo: mostrar que el harness puede leer una fuente controlada y guardar un artefacto.
#
# Tiempo estimado: **1 minuto y 30 segundos**.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from microharness.memory import (  # noqa: E402
    read_harness_context_file,
    read_session_state,
    write_demo_summary,
)

context = read_harness_context_file()
print(context[:900])

# %%
prompt = 'Explícame Agent Harness en 5 bullets para una audiencia técnica.'
summary = '''
- Agent Loop: observar, decidir, usar tools y sintetizar.
- Tools: funciones controladas que aportan capacidades verificables.
- Memory: estado de sesión para continuidad y trazabilidad.
- Planning: descomponer objetivos en pasos controlados.
- Permissions: approvals para acciones sensibles.
'''
state = write_demo_summary(prompt, summary)
print(state)

# %%
print(read_session_state())

# %% [markdown]
# ## Mensaje para narrar
#
# Esta tool representa una integración real. En producción podría ser SharePoint, GitHub, Azure DevOps, Cost Management o un MCP server.
