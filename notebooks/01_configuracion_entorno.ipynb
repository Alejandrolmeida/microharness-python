# %% [markdown]
# # 01 · Configuración de entorno
#
# Primer paso del harness: cargar configuración sin exponer secretos y detectar si hay un modelo disponible.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
ROOT

# %%
from microharness.config import load_settings

settings = load_settings()
{
    'model_configured': settings.is_model_configured,
    'model': settings.model,
    'route': 'base_url' if settings.uses_openai_compatible_url else 'azure_endpoint',
    'host': settings.host,
    'port': settings.port,
    'approvals_enabled': settings.require_confirmation,
}

# %% [markdown]
# El harness puede importarse sin credenciales. El modelo solo es obligatorio cuando se construye el cliente de chat real.
