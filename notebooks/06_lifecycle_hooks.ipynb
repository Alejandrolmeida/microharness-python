# %% [markdown]
# # 06 · Lifecycle con middleware MAF
#
# En vez de hooks llamados manualmente desde la app, la variante MAF-native usa `AgentMiddleware` para peticiones y `FunctionMiddleware` para tools.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
import inspect

from microharness.maf_native import HarnessLifecycleMiddleware, HarnessToolTraceMiddleware

print(inspect.getsource(HarnessLifecycleMiddleware.process))
print("---")
print(inspect.getsource(HarnessToolTraceMiddleware.process))

# %%
from microharness.memory import TRACE_PATH

if TRACE_PATH.exists():
    recent_trace = TRACE_PATH.read_text(encoding="utf-8").splitlines()[-8:]
else:
    recent_trace = []
recent_trace
