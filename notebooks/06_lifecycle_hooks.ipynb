# %% [markdown]
# # 06 · Lifecycle hooks
#
# Los hooks registran eventos alrededor de peticiones y tools para hacer observable el harness.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.lifecycle import HOOKS
from microharness.memory import TRACE_PATH

HOOKS.before_request('notebook', 'Analiza lifecycle hooks')
HOOKS.before_tool('example_tool', {'input': 'value'})
HOOKS.after_tool('example_tool', {'ok': True})
HOOKS.after_request('notebook', 'Hooks registrados')
TRACE_PATH.read_text(encoding='utf-8').splitlines()[-4:]
