# %% [markdown]
# # 03 · Skills y tools
#
# Las skills son funciones Python tipadas que el agente puede invocar para obtener contexto, persistir artefactos o ejecutar una acción controlada.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.tools import HARNESS_TOOLS

[getattr(tool, '__name__', str(tool)) for tool in HARNESS_TOOLS]

# %%
from microharness.memory import write_agent_artifact

state = write_agent_artifact(
    prompt='Describe las piezas del harness.',
    summary='Context Manager, Skills, Sub-agents, Memory, Lifecycle Hooks y FastAPI + AG-UI.',
)
state
