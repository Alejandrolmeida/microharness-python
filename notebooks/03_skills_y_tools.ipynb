# %% [markdown]
# # 03 · Tools, approvals y middleware MAF
#
# Las skills siguen siendo funciones Python, pero el contrato con el modelo lo aporta `@tool` de Microsoft Agent Framework. La variante MAF-native añade middleware nativo para trazas y aprobaciones.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.tools import HARNESS_TOOLS

[
    {
        "name": getattr(tool, "__name__", type(tool).__name__),
        "type": type(tool).__name__,
    }
    for tool in HARNESS_TOOLS
]

# %%
from microharness.maf_native import build_native_middleware

middleware = build_native_middleware()
[
    {
        "middleware": type(item).__name__,
        "source_id": getattr(item, "source_id", None),
    }
    for item in middleware
]

# %%
import inspect

from microharness.maf_native import HarnessToolTraceMiddleware

print(inspect.getsource(HarnessToolTraceMiddleware.process))
