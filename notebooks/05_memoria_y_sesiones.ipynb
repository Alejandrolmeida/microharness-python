# %% [markdown]
# # 05 · Memoria y persistencia de sesiones
#
# La memoria local guarda hechos por sesión, estado del último turno y trazas compactas de tools.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.memory import read_facts, read_session_state, remember_fact

remember_fact('notebook', 'El usuario está explorando memoria de sesión.')
read_facts('notebook')

# %%
read_session_state()
