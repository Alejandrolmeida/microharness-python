# %% [markdown]
# # 02 · ContextProvider nativo de MAF
#
# En la variante MAF-native el contexto ya no se entrega mediante una llamada manual desde la aplicación, sino mediante `ContextProvider` dentro del pipeline de `Agent.run()`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.maf_native import build_native_context_providers

providers = build_native_context_providers()
[(type(provider).__name__, provider.source_id) for provider in providers]

# %% [markdown]
# `HarnessKnowledgeProvider` inyecta el bloque de conocimiento local con `context.extend_instructions(...)`. `FileHistoryProvider`, `TodoProvider` y `MemoryContextProvider` participan en el mismo pipeline de contexto de MAF.

# %%
import inspect

from microharness.maf_native import HarnessKnowledgeProvider

print(inspect.getsource(HarnessKnowledgeProvider.before_run))
