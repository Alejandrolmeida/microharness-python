# %% [markdown]
# # 02 · Context Manager
#
# El context manager decide qué conocimiento local y qué memoria de sesión se entregan al agente.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.context import ContextManager

context = ContextManager().build(session_id='notebook')
print(context.as_prompt_block()[:1200])

# %% [markdown]
# Este bloque es el contrato entre aplicación y modelo: contexto explícito, acotado y auditable.
