# %% [markdown]
# # 04 · Subagentes
#
# Los subagentes mantienen la delegación explícita. Aquí son deterministas para que el flujo sea reproducible y fácil de probar.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
from microharness.subagents import SUBAGENTS

for name in ['architect', 'reliability', 'security']:
    result = SUBAGENTS.run(name, 'Revisar el harness mínimo')
    print(result)
